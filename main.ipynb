# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/Ironhack/Mini_project')

from functions_test import *

# %%
# Dictionaires of every room and objects
import time
import threading
from datetime import datetime

couch = {
    "name": "couch",
    "type": "furniture",
}

piano = {
    "name": "piano",
    "type": "furniture",
}

queen_bed = {
    "name": "queen_bed",
    "type": "furniture",
}

double_bed = {
    "name": "double_bed",
    "type": "furniture",
}

dresser = {
    "name": "dresser",
    "type": "furniture",
}

dining_table = {
    "name": "dining_table",
    "type": "furniture",
}

door_a = {
    "name": "door a",
    "type": "door",
}

door_b = {
    "name": "door b",
    "type": "door",
}

door_c = {
    "name": "door c",
    "type": "door",
}

door_d = {
    "name": "door d",
    "type": "door",
}

key_a = {
    "name": "key for door a",
    "type": "key",
    "target": door_a,
}

key_b = {
    "name": "key for door b",
    "type": "key",
    "target": door_b,
}

key_c = {
    "name": "key for door c",
    "type": "key",
    "target": door_c,
}

key_d = {
    "name": "key for door d",
    "type": "key",
    "target": door_d,
}

game_room = {
    "name": "game room",
    "type": "room",
}

outside = {
    "name": "outside",
}

bedroom_1 = {
    "name": "bedroom_1",
    "type": "room",
}

bedroom_2 = {
    "name": "bedroom_2",
    "type": "room",
}

living_room = {
    "name": "living room",
    "type": "room",
}

# List of all rooms in the game
all_rooms = [game_room, outside, bedroom_1, bedroom_2, living_room]

# List of all doors in the game
all_doors = [door_a, door_b, door_c, door_d]

# Define relationships between objects, rooms, and keys
object_relations = {
    "game room": [couch, piano, door_a],
    "piano": [key_a],
    "door a": [game_room, bedroom_1],
    "bedroom_1": [queen_bed, door_a, door_b, door_c],
    "queen_bed": [key_b],
    "door b": [bedroom_1, bedroom_2],
    "door c": [bedroom_1, living_room],
    "bedroom_2": [double_bed, dresser, door_b],
    "double_bed": [key_c],
    "dresser": [key_d],
    "door d": [living_room, outside],
    "living room": [dining_table, door_c, door_d]
}



# define game state. Do not directly change this dict.
# Instead, when a new game starts, make a copy of this
# dict and use the copy to store gameplay state. This
# way you can replay the game multiple times.

INIT_GAME_STATE = {
    "current_room": game_room,
    "keys_collected": [],
    "target_room": outside
}

# %%
#game_state = INIT_GAME_STATE.copy()

#start_game(game_state, object_relations)

game_state = INIT_GAME_STATE.copy()

# Timer duration in seconds
TIMER_DURATION = 300

# Start the countdown timer in a separate thread
timer_thread_running = False
timer_thread = threading.Thread(target=countdown_timer
                                , args=(TIMER_DURATION,))
timer_thread.start()

# Start the game
start_game(game_state, object_relations)

# Stop the timer thread when the game ends
timer_thread_running = False
# Out:
# Time left: 04:51What is your name?
# Jose
# Time left: 04:50Welcome to the game Jose !
# You wake up on a couch and find yourself in a strange house with no windows which you have never been to before.
# You don't know what happened but you feel that something dangerous is approaching and you must get out of the house.
# Try to find something that might help you leave the house, and FAST!
#
#
#
# You are now in game room
# Time left: 04:33What would you like to do? Type 'explore' or 'inspect'?
# explore
# Time left: 04:32
# You explore the room. This is game room. You find *couch*, *piano*, *door a*
# You are now in game room
# Time left: 04:18What would you like to do? Type 'explore' or 'inspect'?
# inspect
# Time left: 04:15What would you like to inspect?piano
# Time left: 04:14You inspect piano. There isn't anything interesting about it.
# You are now in game room
# Time left: 03:58What would you like to do? Type 'explore' or 'inspect'?
# inspect
# ...
